# %%
import json
import pandas as pd
import csv
import numpy as np
import MeCab
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %%
def readpdCSV(file_pass, file_name, file_type):

    df = pd.read_csv(file_pass+file_name+file_type, dtype={'body': 'str', 'category': 'str'}, encoding="utf-8")

    return df.dropna()

# %%
def septfIdf(df, name):
    body = np.array([])
    pick_term = []
    shihyo_words = []
    for row in df["body"]:
        if(row != "NaN" or row != "nan"):
            noun = sepNoun(row)
            body = np.append(body, noun)

    vectorizer = TfidfVectorizer(use_idf=False)
    vecs = vectorizer.fit_transform(body)
    terms = vectorizer.get_feature_names()
    for vec in vecs.toarray():
        for i, t in zip(vec, terms):
            # if(0.1 <= i <= 0.3):
            if(i >= 0.35):
                flag = 0
                if(pick_term == []):
                    pick_term.append(t)
                    continue
                for v in pick_term:
                    if(t == v):
                        flag = 1
                if(flag == 0):
                    pick_term.append(t)

    print(name)
    print(pick_term)
    print(len(pick_term))
    print("-"*40)
    return pick_term

# %%
def sepNoun(data):
    mt = MeCab.Tagger('mecabrc')
    mt.parse("")
    # print(data)
    node = mt.parseToNode(data)
    # print(node.surface)
    return getNouns(node)

def getNouns(node):
    words = []
    word_stack = ""
    while node:
        noun = node.feature.split(",")
        word = node.surface
        if(checkNoun(noun)):
            word_stack += word
        if(word_stack != "" and noun[0] != '名詞'):
            if(checkNum(word_stack)):
                words.append(word_stack)
            word_stack = ""
        node = node.next
    words = " ".join(words)
    return words

def sepData(df, sepfile_names):
    arr = [[], [], [], [], [], [], [], [], [], [], [], []]
    for data in df:
        # print(data)
        for num, article in data.iterrows():
            # print(article["category"])
            cat_list = article["category"]
            # print(cat_list)
            flag = 0
            for i in range(11):
                # print(cat_list[i])
                if(cat_list[i] == "1"):
                    flag = 1
                    if(arr[i] == []):
                        arr[i].append(["head", "date", "body", "category"])
                    arr[i].append([article["head"], article["date"], article["body"], cat_list])

            if(flag == 0):
                if(arr[11] == []):
                    arr[11].append(["head", "date", "body", "category"])
                arr[11].append([article["head"], article["date"], article["body"], cat_list])

    # print(arr[11])
    for i in range(len(sepfile_names)):
        wc.writeCSV(arr[i], "../csv_sep/"+sepfile_names[i])

# %%
def checkNoun(noun):
    zyogai = ["副詞可能", "非自立", "代名詞", "助詞類接続"]
    if(noun[0] == '名詞'):
        if(noun[1] in zyogai):
            return False
        else:
            return True
        
def checkNum(word_stack):
    mt = MeCab.Tagger()
    mt.parse("")

    node = mt.parseToNode(word_stack)
    while node:
        noun = node.feature.split(",")
        if(noun[1] == '数'):
            return False
        node = node.next

    return True

# %%
def countVect(df, file_names):
    body = np.array([])
    for d in df:
        body = np.append(body, " ".join(d))

    count_vectorizer = CountVectorizer()
    vecs = count_vectorizer.fit_transform(body)
    features = count_vectorizer.get_feature_names()
    # print(features)
    # print(max_count)
    term_countlist = []
    terms = []
    vec = vecs.toarray()
    # print(vec)
    # print(len(vec))
    # それぞれの単語の出現回数をリスト化
    for t, i in zip(features, range(len(features))):
        count = 0
        for num in range(len(file_names)):
            # print(vec[num][i])
            count += vec[num][i]
        term_countlist.append(count)
    # print(term_countlist)

    need_term = []

    for count, f in zip(term_countlist, features):
        if(int(count) < 2):
            need_term.append(f)
    # print(need_term)

    terms_pick = []
    for d in df:
        pick = []
        for term in d:
            for nt in need_term:
                if(str(term) == str(nt)):
                    pick.append(term)

        terms_pick.append(pick)

    # print(terms_pick)

    return terms_pick

# %%
def writeJSON(d):
    with open("../json/word_dict2.json", "w") as f:
        json.dump(d, f, ensure_ascii=False)
    time.sleep(2.0)

# %%
file_pass = "../reuters_csv/reuters_topNews_"
file_type = ".csv"
sepfile_names = ["keiki", "bukka", "kinri", "money", "boueki", "koyou", "kojin", "kainyu", "oil", "kabu", "saiken", "youjin", "seiji"]

# それぞれの予想材料ごとに名詞分割して重み付け
# csvの読み込み
df = []
data = []

# %%
for name in sepfile_names:
    df.append(readpdCSV("../csv_sep/", name, file_type))
# print(df)
print("---csvの読み込み完了---")
# Out:
# ---csvの読み込み完了---

# %%
for d, name in zip(df, sepfile_names):
#     print(d["body"])
    data.append(septfIdf(d, name))
# Out:
# keiki2_2_2
# ['sbihd', 'sbiイートレード証券', 'アンバック', '同行', 'frb', '予想', '前月', '借入金', 'ドル', 'ベアースターンズ', '上昇', '社債', '買収', '投資家', '民主党', '暫定税率', 'やり方', '国内債券', '外国証券', '売却', '各国', '証券化商品', '政府系ファンド', '修正値', '越し', '見方', '発行', '確実性', '運用機関', '有価証券報告書', '発行開示書類', '虚偽記載', '課徴金', '個人向け国債', '資産', '預貯金', 'ihi', '外貨準備', 'ディストレス債', '両社', '可能性', 'フレディマック', '財源', '補正予算', 'アイコン社', '定額減税', 'gse', '国民', 'リーマン', '資金', '見通し', '赤字国債', '追加経済対策', '措置', '円債', '横ばい', '残高', '営業利益', '麻生首相', 'サムライ債', 'デフォルト', '建設国債', '手当て', '引き上げ', 'アーバン', 'パリバ', '日銀', '決定', '野村', '検討', 'ecb', '意見', '対応', '市場', '悪化', 'gmac', '企業', 'ジャンク債', '米国債', 'シティ', 'リスク資産', '購入', '金融機関', 'cp', '中小企業向け', '企業向け', 'ハイブリッド証券', '表明', '上値', '増資', 'ディーラー', 'インフレ率', '野村hd', '委員', '加盟国', '支援', '政策金利', '承認', 'フォード', '現金', '同社', '対策', '必要', '買い入れ', '増額', '長期国債', '影響', '実施', 'キング総裁', 'デフレスパイラル', '下落', '物価', '銀行券ルール', '会談', '経済対策', '銀行', '集中検査', '撤廃', 'gm', '会社', '関係筋', '中国', '米国', '減収', '中心', '経営再建計画', 'gm株', 'uaw', 'クライスラー', 'ゴールドマン', '返済', '公募増資', '観測', '選挙', '富裕層', '普通株', '転換', '修正案', '申請', 'imf', '追加的', 'リオープン', '政府保証', '銀行システム', '伸び', '鈍化', '議論', 'cit', 'エールフランス', '当期利益', '改善', '劣後債', '利払い', '延期', 'ubs', '日本', '展開', '異例', 'ピーク', '欧州', '景気', '判断', '吉利汽車', '状況', 'jal', '説明', '実体経済', '動き', 'pa', '政府', 'マニフェスト', '考え', '特別オペ', '潜在成長率', '入札', '同相', '海外勢', '日立', '拡大', '減額', '目的', '大臣', '財政規律', '予算', '償還', '歳出', '川村社長']
# 187
# ----------------------------------------
# bukka2_2_2
# ['予想', '金融市場', 'ecb', 'トリシェ総裁', '総裁', 'frb', '予断', '経済見通し', '中国', '上方修正', '住宅ローン融資額', 'エコノミスト', '実施', '一致指数', '内閣府', 'リスク', '売上高', '最高', '輸入', '可能性', '評価損', '指摘', '景気後退', '確率', '前月', '小売売上高', 'ドル', '報告', '上昇', '住宅着工件数', '水準', '市場予想', '一段', '減税', '米経済', '直面', '銀行', 'リセッション', '景気対策', '株安', '人民元', '基本シナリオ', '実体経済', '減速', '個人', '文書', '税払い戻し', 'リポート', '法案', '寄与度', '人民銀行', '幹部', '生産', '日銀', '財政赤字', '予算教書', '投資判断', '調査', 'セル', 'インフレ', '日経平均', 'ユーロ', '必要', '金融保証会社', '見通し', '回復', '日本', '景気', '安定', '救済策', '提案', '市場', 'gdp', '成長率', '失業率', 'エクスポージャー', '損失', '取引', '輸出総額', '伸び', '利下げ', 'スロバキア', '欧州委員会', '動き', 'cpi', '豪ドル', 'oecd', '成長', '反発', '欧州委', '債権回収業者', '発表', '修正', 'インフレ期待', '懸念', '更新', '高値', '回答', '消費', '寄り付き', '商品', '速報値', 'スタグフレーション', 'メドベージェフ氏', 'rba', '円高', '世界経済', '減少', '数字', '設備投資', '問題', '福井総裁', '投資家', 'eia', '達成', '数値', '記録', '足元', '非常', '落ち込み', '設備稼働率', '収入', '決算', 'キャッシュ', '拡大', '増加', '金融株', '講演', '暫定税率', '計画', 'ノーザン', '議長', '証言', '株価', '伸び率', 'ベトナム', '民間エコノミスト', '投機筋', 'マイナス成長', '同社', '利益', '着工件数', '許可件数', '基準', '影響', '悪化', '先行き', '対策', 'nar', 'bba', '政府', '消費者', '赤字', '中央値', '大勢見通し', 'バブル', '新設住宅着工戸数', 'fomc', 'adb', '住宅ローン', 'ブラウン首相', '需要', 'ubs', '生産性', 'ユーロ導入', '首相', '資産', 'ガソリン価格', '発言', '鈍化', '個人消費', '信認', '輸出', '黒字', '投資', '四川省', '議事録', '欧州', '地震', '原油価格', '上乗せ', '燃料費', '介入', '自国通貨', '途上国', '主導', '下方修正', '海外勢', '下落', '住宅価格', '米国', 'ドルペッグ制', '日本株', '英国', '物価安定', '金融政策', '下半期', '金利', '安値', 'mba', 'ci', '低下', 'グローバル化', '促進', 'トヨタ', 'ハイブリッド車', '研究員', '実質gdp', '延滞率', 'マイクロソフト', 'ヤフー', '金融引き締め', '会合', 'そう', '鉱工業生産', '認識', 'グループ', 'ceo', '見方', '議論', 'sifma', 'トゥンペルグゲレル専務理事', '利上げ', '改定段階', '次期大統領', '企業', '前回調査', '産業', '米企業', '長官', '兆候', '報告書', '東証', '焦点', '現時点', '全会一致', '判断', '財務相', '先進国', '前回', '中期的', 'ファニーメイ', 'フレディマック', '貿易赤字', '支援策', 'インフレ率', 'メンバー', '調整', 'imf', '回答者', 'コアインフレ率', '地区', 'ブラジル', '設定', '歳入', 'カバードボンド', '状況', '金融機関', 'cdo', 'シティ', 'ファンド', 'カナダドル', '政策金利', '反対票', 'すかいらーく', '前月調査', '下値', '横ばい', 'マイナス', '経済対策', 'クロス円', 'ガソリン', 'スペイン', '内需', '都市部固定資産投資', '自動車部品', '大統領', 'フランス', '停滞', '委員', 'mapi', '予測', 'ホープナウ', '家計', '米景気', '総合指数', '大幅', '新規受注', '原油', 'タイ', '主張', '増値税', 'ホームデポ', '推定値', '製造業', '強調', '差し押さえ手続き', '金融危機', 'ci一致指数', 'リーマン', 'アジア', '下方修整', '韓国', '縮小', 'hbos', '買収', 'cb', '先行指数', '消費税', 'オフィスビル', '金価格', 'インド', 'スズキ', '経済指標', '商品価格', '声明', '日本経済', 'アナリスト', 'オバマ氏', '重要', 'ダウ', '強化', '軟調', 'レバレッジ', '住宅ローン金利', 'ロイター', 'gdp伸び率', '中国国家統計局', '国内', '効果', 'ポジション', 'アイスランド', '上昇率', '改善', '景気刺激策', '厳格化', 'ppi', '措置', '低迷', '最大', 'デフレ', '住宅建設', '四半期', '資産価格', 'グロス経済技術相', '差し押さえ', 'eu', '耐久財受注', 'bo', 'クリスマス商戦', 'nrf', '商戦', '急速', '協調', 'nber', '流動性', 'ユーロ圏', '中間値', '百貨店', '協議', 'ロイター予測', 'デフォルト', '指示', '減少幅', '明示', '税制抜本改革', '卸売在庫', 'tarp', '財務省', '価格下落', 'ロシア', '批准', '麻生首相', 'コア指数', 'gm', '目標', 'パナソニック', '北朝鮮', '公聴会', 'シンガポールドル', '調査局', '展望リポート', 'レンジ', '底値', '事業', '金融システム', '解散', '英国経済', '国家統計局', 'ケース', '基礎的財政収支', '実現', 'item', '鉱工業受注', '最低', 'ノーザンロック', '支出', '小売業界', '香港', '利回り', '米国債', 'ing', 'ポンド', '政策', '在庫', '温家宝首相', '上院', '共和党', '資金', 'cmo', 'mbs', '決定', '銀行救済策', '中国経済', '住宅保有者', '統計局', '記者会見', '辞任', '署名', '支援', 'エネルギー価格', '削減', '世界', '崩壊', '円買い', '融資', 'ギリシャ', '予算案', 'ntt東', '債務', 'aig', '金融安定化策', '会議', '定額給付金', '支給', '借り手', 'aiada', '申請総数', '対応', '応札', '雇用庁', 'ge', 'スイスフラン', '対ユーロ', '財政出動', '下落幅', 'jplh', 'ラブホテル', 'キング総裁', '受注', '改定値', 'オバマ大統領', '中小企業', '数値目標', '英経済', '集中検査', '受給総数', '成長率予測', '撤回', '確信', '経済', '上海総合株価指数', '指数', '対gdp比', '専務理事', '感染', '東京市場', 'メキシコ', 'メキシコ経済', '豚インフルエンザ', 'サーベラス', '融資基準', 'アナリスト予測', '既存店売上高', 'データ', '委員会', '承認', '新規融資', '選挙', '増配', '景気回復', '訂正', '局長', '正社員', '幾分', '正常', '長期的', '株式保有リスク', 'fsa', '買い', 'gdpギャップ', 'デュレーション', 'ポートフォリオ', '手掛かり', '約束', '英中銀', 'ストレステスト', '歳出改革', '機関', '各国', '兆し', 'リアルティトラック', '候補', '投票権', 'ダーリング財務相', '改革案', 'cbo', '国務院', '経常赤字', 'ドイツ', 'bis', 'cfnai', 'トレンド', '経済成長率', 'vix指数', '米ドル', '耐久財', '独立性', '売り上げ', '自動車', '解除', 'エコノミスト予想', '加速', '一戸建て住宅', 'cit', 'カメ', '賃金', '脅威', '好調', 'チャインドネシア', '民主党', '期待', '維持', '雇用喪失', '失業給付', '前月比', '個人消費支出', 'is ...
# 629
# ----------------------------------------
# kinri2_2_2
# ['共和党', '民主党', 'ドル', '議論', '介入', '自国通貨', '外貨準備', '米国', '変動', '検討', '日銀', 'シンガポールドル', 'ドル買い介入', '上昇', 'ルーブル', '介入水準', '中国', 'ユーロ', '円高']
# 19
# ----------------------------------------
# money2_2_2
# ['利下げ', 'fomc', 'frb', '発表', '経済', '雇用統計', 'ブルーチップ', '調査', 'クレジットカード', '可能性', '指摘', '景気後退', '確率', 'シティ', 'ポートフォリオ', '評価損', '米経済', '増加', 'リセッション', 'ilo', '個人', 'ドル', '上院', '長官', '景気対策法案', '失業率', 'ecb', '水準', '緊急利下げ', '円高', '影響', '企業', '利益見通し', '見通し', '動き', '失業者数', '減少', '予想', 'そう', '効果', 'jpモルガン', '景気対策', '減少幅', '個人消費', '総務省', '下落', '住宅価格', '原油価格', '下半期', '東京市場', '日経平均', '海外勢', 'ムーディーズ', '日本', '集計', 'gm', '新規雇用率', '数字', '農業部門雇用者数', '政策金利', '景気', '前月調査', 'スペイン', '金融株', 'mapi', '予測', '大幅', '状況', '市場', '軟調', '実施', '増加幅', '連携', '前月', '雇用創出', '資産価格', '金融政策', '失業保険', '失業対策法案', '延長', '給付期間', '上昇', '記録', '売上高', '住宅ローン', 'オバマ次期大統領', '雇用', 'エコノミスト', '悲観的', '小売業者', '閉店', '財政赤字', 'ナスダック', '悪化', 'cnbcテレビ', '内容', '方向性', '検討', '米国', 'ブッシュ大統領', '同氏', '季節調整後', 'カメ', '融資', 'ユーロ圏', '全人代', '委員会', '不況', '先進国', '政策対応', '正当化', '雇用者数', '赤字', '大統領', '銀行', '雇用庁', '倒償却率', '恐慌', 'oecd', '消費者', 'talf', '議事録', '物件', '内閣府', 'フィッチ', '完全失業率', '回復', 'ストレステスト', 'フィアット', '必要', '成長', 'インフレ', 'fsa', 'rba', 'ユーロ', '見方', 'リアルティトラック', '差し押さえ', '候補', '利上げ', '投票権', 'デフォルト率', '刺激策', '現時点', '懸念', 'バフェット氏', '議長', '賃金', '失業給付', 'ポンド', '成長率', 'オバマ大統領', '再任', '英ポンド', '委員', '下げ', '四半期', 'cbo', 'ホワイトハウス', '正社員', '個人所得', '上方修正', '中国', '緩やか', '報告書', '価格指数', 'サービス業', '改善', '消費者信用残高', '就業者数', 'ceo', '世界経済', '意見交換', '変動', '論評', '指数', '低下', '民主党', '新規失業保険週間申請件数', '更新', '突破', '節目', '米雇用統計', '金現物', '高値', '選択肢', 'プラス', '伸び', '価格帯', 'aig', '破たん', '赤字額', 'nabe', '問題', '非常', '報告', 'ism', '責任', '金融機関', '演説', 'イリノイ州', '雇用対策', 'プライマリーディーラー', 'ドル買い', '判断', '法案']
# 206
# ----------------------------------------
# boueki2_2_2
# ['原油価格', '可能性', '対処', '石油備蓄', '上昇', '原油', '日経平均', '取引', '米市場', '高値', '安値', 'アナリスト', '原油在庫', '世界経済', '影響', '最高', '輸入', 'ブッシュ大統領', '協議', '日本', '経常黒字', '貿易収支黒字', '総裁', '米国', '下方修正', '減税', '下落', '株価', '社長', '米経済', '輸出', '増加', 'ダウンサイドリスク', '製油所', 'opec', '増産', '景気', '会合', 'ベネズエラ', 'eia', '減少', 'アナリスト予想', '予想', 'frb', 'リセッション', '品目', '回答', '消費者', '中小企業', '更新', '修正', '動き', '背景', 'ドル', '支持', 'ドル安', '円高', 'fomc', 'そう', '値動き', '九州石油', '日石', '軽自動車', 'メリルリンチ', 'imf', '投資家', '原油相場', '同氏', 'インフレ', 'ups', '輸入価格', '輸出価格', '議論', '懸念', '先行き', '見方', '指摘', '高山', '効果', 'bp', '英国', '利益', '市場予想', '配当', '利下げ', 'ファニーメイ', 'リサーチノート', '同相', '状況', 'aig', 'rim', '利食い', '金融株', '市場', '黒字', 'サウジアラビア', '買い', '東京市場', '議事録', '反映', '長期的', 'ユーロ', '上値', '寄り付き', 'ニューヨーク取引', '金現物', '上乗せ', '燃料費', '主導', '海外勢', '物価上昇', '合意', '決算', 'ドルペッグ制', '西尾社長', 'ecb', '個人投資家', '理事会', '姿勢', '需要減退', 'グローバル化', 'トヨタ', 'ハイブリッド車', 'iea', '中国', 'gdp', '利上げ', 'swf', 'ガソリンスタンド', '保有', '金融引き締め', '伸び', '成長', '発表', 'サウジ', '越し', '前週', 'サミット', 'メッセージ', '西久保社長', '運用機関', '議会', 'モルガンスタンレー', '商品トレーディング', '水準', 'バイオ燃料', '急伸', '日本株', '法案', '米原油需要', '長官', '報告書', '打撃', 'nymex', 'gm', '焦点', '現時点', '必要', 'ge', '続落', '戻り', '食料', '財務相', '支援', 'イラン', 'レジ袋', 'ゴミ', '太陽光', 'エコノミスト', '消費', '見通し', '大統領', '戦略備蓄石油', 'ウェルズファーゴ', '製造業', '委員', '同社', 'ブラジル', '設定', '電気料金', '可決', '同案', '需要', 'オバマ氏', '反対票', '想定', '供給ひっ迫', '減速', 'ppi', 'ヘッジファンド', '輸入物価', '反発', 'キューバ', '米原油先物', '先物', '金本位制', 'gse', 'グルジア紛争', 'ロシア', '見解', '日銀', 'oecd', '被害', '深刻', '下値', 'リーマン', '高水準', 'アジア', '赤字', 'インド', 'スズキ', '鈴木会長', '太陽電池', '薄膜式', '上方修正', '減産', '鉱山機械', '縮小', 'アルカイヤ氏', '勝利', 'マイナス', '信用倍率', '国際商品市況', '嫌気', '決定', 'デフレ', 'ユーロ圏', '統合', 'ホンダ', '低下', 'iata', '価格下落', '質問', '大幅', '悪化', 'コンビニ', 'pa', 'ルーブル', 'gmac', '北海ブレント原油先物', '推移', '欧州市場', '通年', '展望リポート', '最新', 'ポジティブ', '最大', 'アナリスト予想平均', 'ロイターエスティメーツ', '集計', '問題', '海外投資家', 'ナノ', '減少率', '米政府', '反落', 'インフレ率', '改善', 'ガソリン価格', '回復', '消費国', '産油国', '予測', '状態', '候補', 'アンドレス', '大雨', '航空業界', '週足', '店頭デリバティブ', 'エールフランス', '公募増資', '予想外', '中国株', '当期利益', '日量', '利益確定', '予定', '新た', 'インフレ期待', '展開', 'クラフト', '前週比', '余剰生産能力', '損失', '雇用統計', 'ドル建て', '生産目標', '準備通貨', '好感', '序盤', '先行', 'エネルギー', '日揮', '拡大', '総会', '要望']
# 297
# ----------------------------------------
# koyou2_2_2
# ['回復', '減速', 'リスク', '動き', '前月', '売上高', '小売売上高', 'nrf', '悪化', '下方修正', '増加', '委員', '世界経済', '景気', '利下げ', '実施', 'frb', '先行き', '値上げ', '上昇', '可能性', '円高', '足元', '暫定税率', 'gm', '推移', '予想', '調査', 'ドル', '発表', '懸念', '信用', '消費者', 'ecb', '個人消費', '低下', '高水準', '東京市場', '鈍化', '影響', '主導', '物価上昇', '決算', '下落', '住宅価格', '報告', '判断', '製造業', '税還付', '数字', '伸び', 'fomc', 'aig', 'マクドナルド', '横ばい', 'マイナス', '経済対策', 'スペイン', '反発', '市場', '停滞', '消費', '家計', '大幅', 'ロイター', 'ceo', 'ホームデポ', '地区', '設備投資', '鉱工業生産', '縮小', '前回', 'ピーク', 'トヨタ', 'gdp', 'cbi', '住宅建設', '四半期', 'クライスラー', '稼働停止', '決定', '支出', '企業', '見通し', '減少', '小売業界', '香港', '利回り', '米国債', '消費支出', '個人所得', '厳格化', '既存店売上高', 'gmac', 'fhfa', '米国', '融資', '委員会', 'ge', '認識', '定期昇給', '雇用', '規模', 'コア指数', '株価', '中小企業', '申請', '値下げ', '景気後退', '小型店', '改善', '現状維持', '破産', 'メキシコ', 'エコノミスト予想', '融資基準', 'アナリスト予測', '予測', '内閣府', '日本', '原油価格', '景気対策', 'rba', '失業率', '延滞率', '最高水準', '上方修正', '賃金', 'キャタピラー', '兆候', '効果', '利上げ', '個人消費支出', '富裕層', '政権交代', '英ポンド', '維持', '中国株', '利益確定', '米原油先物', '民間', '物価', '景気回復', '成長', '中国', '輸出', '価格指数', '政府', '岡崎氏', 'imf', '内容', 'ユーロ', '週足', '日銀', '消費者態度指数', 'ホリデーシーズン', '販売', '高値']
# 158
# ----------------------------------------
# kojin2_2_2
# ['伸び', '流入', '必要', 'モノライン', 'エクスポージャー', '損失', 'cpi', '金利', '中小企業', '商品', '中国', '外貨準備高', '額賀財務相', '伸び率', '拡大', '発表', 'ドル', 'ファンド', '高値', '利下げ', 'jpモルガン', 'ベアースターンズ', '米国', 'frb', '供給', '前週', '人民元', 'ヘッジファンド', 'ユーロ', 'ecb', '金融市場', '上昇', '買い', '増加幅', '外貨準備', '確実性', '株価', '続落', '可能性', 'ブラジル', '設定', '状況', '経済対策', '総裁', '実施', '下落', '両社', '投資', 'メガバンク株', '影響', '予想', '地価', 'マーケット', '銀行', 'imf', '日銀', '検討', '予定', '米ドル', '措置', '調査', '指摘', '残高', '運用会社', '分配金', '決定', '流出超', 'gm', '議会', '前場', '三洋', '減少', '関係筋', 'グロソブ', '中央銀行', '預金準備率', '支援', '財務省', '申請', '中小企業向け', '企業向け', '対応', '日本', 'インフレ', '増加', '記録', '市場', 'プログラム', 'aig', 'マス富裕層', '政策金利', '見通し', '承認', '委員会', 'cp', '増額', '長期国債', '中国株ファンド', '前月', '政投銀', '撤廃', '在庫調整', '早川支店長', 'ubs', '資本増強', '与信関係費用', 'ムーディーズ', '格付け', '前期', '担保', '懸念', '手掛かり', '状態', 'ロシア', '米国債', '回復', '世界', '鈍化', '英中銀', '脅威', '公募増資', '投信', '流れ', '海外勢', '委員', 'リサーチ', 'プロジェクト', '異例', '円高', '日本株', '流動性', '判断', '前回調査', '潜在成長率', '純増', '景気', '増資', '課題', '金融機関', '短期金融市場', '政府', '目的', '金現物', '政策', '見方', 'ギリシャ', '法的整理']
# 147
# ----------------------------------------
# kainyu2_2_2
# ['ドル', 'ユーロ', 'ecb', '予想', '損失', 'frb', '利下げ', '理事会', '報告', '動き', '下落', '据え置き', '物価安定', '調査', '措置', 'rba', '政策金利', '実施', '見通し', '日本', '景気', '物価上昇', '豪ドル', 'リセッション', '利上げ', '配当金', '世界経済', '米経済', 'エコノミスト', '発表', '福井総裁', 'ベアースターンズ', '上昇', '社債', '公定歩合', '可能性', '市場', '更新', '日経平均', 'ドル安', 'ff金利', '効果', '緩和政策', '流動性', '供給', '提案', '総裁', 'トヨタ', '東電', '配当利回り', '輸出', '株価', '国内債券', '外国証券', 'グリーンスパン氏', '景気減速', 'fomc', '見方', '回答', '発行', '需要', '低下', 'ニュージーランド', '上値', '日銀', 'nzier', '資産価格', '海外勢', '金融政策', '安値', '影響', '年内', '判断', 'リスク', '減速', '議事録', 'sifma', '原材料高', 'gpif', '運用', '東京', 'インフレ', '同相', '達成', 'インフレ率', 'メンバー', '金融政策委員会', 'コアインフレ率', 'ブラジル', '設定', 'ディストレス債', '状況', 'imf', '個人', '反対票', '成長', '準備預金', '短期金利', 'イングランド銀行', '横ばい', '大統領', '停滞', '対応', 'オフィシャルキャッシュレート', 'オーストラリア準備銀行', '中央銀行', '主張', 'aig', 'mmf', '悪化', '欧州', '金融危機', '換金', 'オバマ氏', '大和生命', 'mスタンレー', '普通株', '金融市場', '住宅ローン金利', '円債', '残高', '白川総裁', 'トリシェ総裁', '会合', 'pimco', '量的緩和', '決定', '引き下げ', '訂正', '豪中銀', '委員', '水準', '必要', '用意', 'cbi', '指摘', '提供', '英中央銀行', '検討', '追加利下げ', 'レポレート', 'snb', 'eu', '銀行', '手段', '山口氏', '円高', '市場機能', '中国人民銀行', '預金準備率', '英中銀', '投資家', '米国債', '金利', '英国経済', 'リスク資産', '購入', '重要', '中国', '利回り', '表明', '外貨準備高', '議論', 'ディーラー', 'ロート総裁', '物金利', '委員会', '講演', '議長', '外銀', '邦銀', 'ローン金利', '英国債', 'スイスフラン', 'スイス中銀', '対ユーロ', 'cp', '下限', '買い入れ', 'オーバーウエート', 'キング総裁', '銀行券ルール', 'oecd', '運用利回り', '撤廃', 'gm', '会社', '関係筋', '議会', 'デフレ', '富裕層', 'ポンド', '長期金利', '担保', '失業率', '基礎利益', '前月', '懸念', 'デュレーション', 'ポートフォリオ', '各国', '入札', 'リオープン', '政府保証', '上方修正', 'libor', 'インフレ期待', 'cfpa', '独立性', '予算合理化', '民主党', '維持', '米ドル', '目標', '拡大', '回答者', '主要通貨', 'プログラム', '規模', '資産買い入れプログラム', '製造業', '財政赤字', '豪経済', '特別オペ', '伸び', '国債市場', '鳩山内閣', '回復', '声明', '報告書', '信頼', '英国', '国債', '投機マネー', '新興国', '前回', '抑制', '減額', '短期金融市場', '目的', '消費税', '非常', 'ge', '内容', 'ドル買い', '大勢', 'デフレスパイラル']
# 247
# ----------------------------------------
# oil2_2_2
# ['中国', '新華社', '貿易黒字', '経常黒字', '貿易収支黒字', '減少', '発表', '輸出', 'リポート', '減速', '寄与度', '政府系ファンド', '最高', '輸出総額', 'cpi', '金融市場', '問題', '輸入', '赤字', '増加', '自動車', '財務省', '日銀', '修正値', '越し', 'swf', '黒字', '伸び', '影響', '増加幅', '外貨準備', 'gdp', '投資', '寄与', '報告書', '上昇', '貿易赤字', '関係筋', '見通し', '記録', '黒字幅', 'ドル', '予想', 'アジア', '貿易収支', '市場', '報告', '介入', 'imf', '景気刺激策', '訂正', '人民元', '減少率', '日本', '米国', '最大', '低下率', '輸入物価', '英国', 'ポンド', 'ルーブル', 'ロシア中銀', '資金繰り', '株価対策', '大幅', 'frb', '必要', '水準', '経常利益', 'メキシコ', '回復', '中国経済', 'データ', '成長', '減少幅', '縮小', '経常赤字', '経常収支', '前月', '高水準', '労働日数調整後', 'ドル安', '金融サミット', '世銀', '拡大', '方針']
# 86
# ----------------------------------------
# kabu2_2_2
# ['年間', '日経平均', '上昇', '上場', '関係筋', '発表', '回復', 'ナスダック', 'うわさ', '検討', 'ceo', '下落', '大幅', '寄り付き', '最悪', '高値', '安値', 'ジンクス', '日本株', 'リスク', '金額', 'グロソブ', '流入', 'ジャスダック', '交渉', '大証', 'ドルベース', '円高', 'メリル', 'sbihd', 'sbiイートレード証券', '邦銀', '予想', '利益率', '売上高', '世界経済', '動き', '影響', '時点', 'ドル', '円買い', '更新', '損失', '米国', 'そう', '買い', 'vix指数', '市場', 'シティ', '小売売上高', 'モノライン', '展開', '解決', '下落幅', '国内証券', '後場', 'pa', '推移', '米経済', '認識', 'ユーロ', '直面', '銀行', 'トロント', '米株市場', '利下げ', '水準', 'インド', 'チダムバラム財務相', '急落', '株価', '決定', 'アブダビ市場', 'オマーン市場', 'ドバイ市場', 'frb', '日本', '株安', 'プルデンシャル', '中国', '対応', '金融保証会社', '減速', '日銀', 'wｉｉ', 'セントレックス', '不備', '金融庁', '検査', '提出', '不正取引', '同行', '上海総合指数', 'fomc', '調査', 'アジア株', '為替', 'jpモルガン', '前回', 'tac', '同社', '減益', '人民銀行', '幹部', 'ゴールドマン', 'ドル建て', '円建て', '利益', '税引き', 'mbia', 'システム', 'マイクロソフト', 'ヤフー', '週足', '可能性', '先行', '日産', 'ヘッジファンド', 'ローンスター', '東京スター銀', 'キヤノン', '三浦社長', '同氏', '売却', '気配', 'ソジェン', '下方修正', 'アデランスhd', 'スティール', '海外勢', 'ダウ', '金融機関', 'エディター', '除外', '公的資金', 'ローソン', 'バフェット氏', '提案', '中国株式市場', '休場期間中', '取引', 'アジア', '前月', '材料', '行使', 'dic', 'ソニー', '値上げ', '運用成績', '日本政府', 'tci', '上値', 'sbi', '取引所', '方向', 'ファニーメイ', 'スクラップ価格', 'ibm', '同社株', '回答', '消費', 'ｉpｈｏｎｅ', 'カード会社', '合併', 'aig', 'tob', 'ら銀行', '背景', '配当金', '改善', '先物', '御手洗会長', '投資家', '同意', '野党', '日興cg', '日興シティhd', '達成', '足元', '足利銀', '公定歩合', 'ドル安', '決算', 'キャッシュ', '減少', '地銀連合', 'ベアー', '公示地価', 'イオン', '金融株', 'ダイエー', '原油', '買収', 'ccb', '出資', '一般財源化', 'hfc', 'hsbc', 'kvam', '暫定税率', '含み益', '指摘', 'リーマン', '転換優先株', '悪化', '優先株', '富士重工', 'トヨタ', '東電', '配当利回り', 'etf', '企業', '計上', '評価損', '総裁', 'ベトナム', '値動き', 'ups', 'ボーイング', '赤字', '時価会計', 'レッドチップ企業', '予想外', '相場', '修正値', '越し', 'インテル', '懸念', '共同持株会社', 'アナリスト', 'ut', '考え', '中止勧告', '政府', '上海総合株価指数', '発行', 'ちょ銀行', '銅山', '低下', '液晶テレビ', '企業業績', '三洋電機', 'サブプライム問題', '増加', 'ウォール街', 'バブル', '利上げ', '配当', '期待', 'アップル', '投資', '機関投資家', '議決権優先株', 'rim', 'インド企業', '地震', '上海', '売買停止', 'ウエストパック銀行', 'セントジョージ銀行', '発言', '増資', 'ストップ高', '続伸', '復興作業', 'トムソンロイター', '人員削減', '株主', '伸び', '東京市場', '信頼感指数', 'グーグル', 'ロシア', '輸出', 'sec', '格付け', '資産価格', '主導', 'gm', '株主総会', 'sebi', '当期', '原油価格', '郵便事業会社', '電気自動車', '電池関連株', '運用', 'ファンド', '個人投資家', '米金融機関', 'ソフトバンク', '成長', 'jパワー', '日本ファンド', '姿勢', '商業銀行', 'サウスイースタン', '日本興亜損保', '水着', '軟調', '資金', '金融引き締め', 'cpi', '運用機関', 'hd', '第一生命', '個人', '業績見通し', 'バークレイズ', '顧客', '製造業', '前場', '薄商い', 'ゴーンceo', '反発', 'イスラエル', 'イラン', 'チャンス', '米企業', '東証', 'ホンダ', 'あと', '必要', '続落', '戻り', '支援', 'フレディマック', '報道', '米財務省', 'gse', 'モーゲージ市場', 'ウェルズファーゴ', '決算発表', 'ゼファー', '市場予想', '停止', 'ワコビア', 'ual', 'swf', '救済策', 'ブラジル', '設定', '銀行株', 'インフレ', 'coo', 'kia', 'イーバンク銀行', 'オリックス', 'クレディセゾン', '収入', '営業利益', 'マクドナルド', '下値', 'gdp', 'クロス円', '空売り', 'unbc', '三菱ufj', '両社', 'ムシャラフ大統領', 'tob価格', '対策', '景気対策', 'アーバン', '見方', 'パリバ', 'アコム', 'ホームデポ', 'モーザーベアソーラー', 'ゲーム業界', '豪ドル', '国際会計基準', '実施', '措置', '保有', '明らか', '金融セクター', 'tbs', '楽天', 'カメ', 'メガバンク株', 'ソウル株', '香港株', '経営破たん', '状況', 'モルガンスタンレー', 'rbs', 'bbcテレビ', 'hbos', '下落率', '不安感', '米市場', '長官', 'mmf', '印紙税', '株価支援策', '地価', 'rtc', '米当局', '開示', '訂正', '三菱ufjfg', '金融安定化策', 'ipo', '現金化', '見通し', 'mスタンレー', 'fdic', '下げ', '議員', 'ネガティブ', '格付けアクション', '可決', 'ヒポレアル', '欧州', '終了', '換金', '選挙', '承認', '参院', 'アンダーウエート', '三井住友', '条件', '不安', 'bp', 'フォード', 'マツダ', '普通株', 'モルガン', '声明', '計画', '規制', '確定申告', '資本注入', '強化', 'reit市場', 'レバレッジ', 'シティグループ', '介入', '外国株式投信', '口座開設', '景気', '世界的', '自国', 'バブル後', 'リスク回避', '安値圏', '日経平均株価', '乱高下', '大手証券', '指示', '大幅安', '終値', '変動', '急激', '急速', '中川財務金融担当相', '大幅続落', '過度', '圧迫', 'スタート', '野村', '全額保護', '預金', 'asbj', '残高', 'ge', 'vw', 'ポルシェ', '上昇率', '基準', '猶予期間', 'アルカイヤ氏', '民主党', 'パナソニック', '設定額', '勝利', '米大統領選挙', '水道哲学', '自己資本比率', '景気刺激策', '金融危機', 'ttsl', 'ドコモ', '優先出資証券', '最大', '分配金', '世界景気', 'キリン', 'コカコーラアマティル', 'ライオンネイサン', 'マイナス', 'スズキ', 'ヤンceo', 'コーエー', 'テクモ', '持ち株会社', 'ベース', 'mscb', '銘柄', '選択肢', 'ガイトナー総裁', '指名', '表明', 'boa', 'tarp', 'gs', '自社株買い', 'ドレスナー銀行', '生産', '政権', '指数', '事件', '日本郵政', 'bo', '市場関係者', 'ルフトハンザ', '任天堂', '株高', 'sq', '合意', 'カマズ', 'ダイムラー', '米自動車大手救済法案', '三菱商事', '予定', 'ジョブズceo', 'マックワールド', '三洋', 'マネーマーケットファンド',  ...
# 822
# ----------------------------------------
# saiken2_2_2
# ['年間', '前回', '可能性', '悪化', 'ドル', '小売売上高', 'ユーロ', '対応', '減速', '支出', '日経平均', '金融保証会社', 'eia', '減少', '上昇', '先行き', '物価上昇', '農水省', 'dic', 'ソニー', 'cpi', '品目', '回答', '消費者', 'frb', '低下', '指数', '総裁', '影響', 'rba', 'ecb', '推移', '達成', '動き', 'イオン', 'ダイエー', '水準', '供給', 'コアコアcpi', '内閣府', '消費者物価指数', '発表', '石油製品特殊要因', '試算', '買い', '収益性', 'インフレ', '価格', 'シャープ', '液晶パネル', '伸び率', '見通し', '値動き', '加速', '伸び', '市場', '予想', '世銀', '成長', 'ジャガイモ', '中国', '政府', 'ヘッジファンド', '決算', '最大', 'fomc', '中央値', '大勢見通し', 'リサーチノート', '後場', 'ガソリン価格', '為替', '高水準', '投資', '原油価格', '搭載', '増加', '海外勢', 'インフレ期待', 'ロイター', '金融政策', '安値', 'リスク', '研究員', '上値', '意見', 'gdp', 'そう', '必要', '支援', '上昇圧力', 'エコノミスト', '消費', '下方修正', '景気', '製造業', 'コアインフレ率', 'cpi上昇率', 'ppi', 'スペイン', '家計', '前月', '上海総合指数', '総合経済対策', '対策', 'クロス円', '利下げ', '大和生命', '報告', '上方修正', '住宅価格', '地域', '値上げ幅', '電気料金', '調査', 'gm', 'nar', '食品価格', '鈍化', '総合指数', '中間値', '減少幅', '景気対策', '価格下落', '報告書', '目標', '山口氏', 'シティグループ', '救済', '日銀', 'pa', '通年', '調査局', '展望リポート', '中央銀行', 'ナスダック', 'rbs', 'ge', '期待', 'ハイブリッド証券', '上昇率', '下落', '損失', '景気対策法案', 'シティ', '国有化', 'エネルギー価格', '予測', '空売り', '改善', '金融機関', 'oecd', 'メキシコ', '米国', 'マイナス', '局長', '財政赤字', '落ち込み', '回復', '金属原油価格', '判断', '業種', '週足', '解除', '見方', 'インフレ率', 'プラス', '前月比', '大幅', '利益確定', '米原油先物', '値上がり', '政権', 'クラフト', '物価', '政策金利', 'スイスフラン', 'コアcpi', '縮小', '信頼感', '史上', '高値', '消費者信用残高', '長官', '潜在成長率', '内容', '北朝鮮', '計画', '赤字', '維持', 'デフレ', '前期比', '大勢', '物価安定', '理解', 'ダウ']
# 196
# ----------------------------------------
# youjin
# ['住宅価格', '比率', 'hd', 'jpモルガン', '予想', '利下げ', 'fomc', 'frb', '調査', '低迷', '住宅市場', '政策', '経済', '検討', '選択肢', '景気後退', '損失', '必要', '予断', '経済見通し', 'ドル', '下落', 'イラン', '世界経済', '米国', '法案', '実現', '退任', '議長', 'ルービン氏', '見通し', '金融市場', '可能性', '日本', 'nrf', '伸び', '指摘', '確率', '増派', '派遣', '欧州', '妥当', '支出', '総裁', '北朝鮮', '核計画', '申告', 'ユーロ', '影響', 'ceo', '問題', '回答', '下方修正', '景気', '減速局面', '米経済', '金利', '減速', '正常', '物価安定', '見方', 'ecb', '議会', '景気対策', '融資', 'オバマ氏', '勝利', 'インディアナ州', 'クリントン氏', '総合経済対策', 'カトリーナ', 'ハリケーン', '緊急対策', '中国', '大統領', '格付け', '決定', 'fdic', '強調', '差し押さえ手続き', '回復', '議論', '逆風', '措置', 'アジア', 'aig', '金融機関', '消費税', '経営者', '深刻', '金融危機', '海外経済', '確信', '状況', '解散', 'ブッシュ政権', '法律', '途上国', '金融ひっ迫', 'ブッシュ大統領', '中川財務金融相', '協調', '対策', '軟調', '国際社会', 'イタルタス通信', 'gm', '政府', 'ロシア', 'エコノミスト', 'プラス成長', '声明', '金融政策', '課題', '取り組み', '米国債', '疑問', '選挙', '情報']
# 119
# ----------------------------------------
# seiji
# ['オバマ上院議員', '予備選', '候補者', '勝利', '民主党', '米nbc', '選出', '北朝鮮', '爆弾', '米国', 'オバマ氏', 'ワイオミング州', '事態', '支持率', '獲得', 'クリントン上院議員', 'ニューハンプシャー州予備選挙', '予想', '米大統領選挙', 'クリントン氏', '撤退', '知事', 'wto', '金融機関', '下方修正', 'hud', '問題', '辞任', '福田首相', 'シリア', '払い戻し', '経済対策', 'frb', '見通し', '会合', '公表', '日銀', 'ウォール街', '文言', '大統領選挙', '民主党ノースカロライナ州予備選', '米メディア', '民主党インディアナ州予備選', '米cbsテレビ', '首相', '福田康夫氏', '辞任表明', 'ロシア', '停止', '操業', '製油能力', '核施設', 'コミュニティ', 'ペイリン知事', 'グルジア', '両社', 'イラク', 'ペイリン氏', '国民', '書記', 'オバマ候補', '交渉', '複数', '関係筋', 'アジア市場', '取引開始', '売却', '完了', '発表', 'ゴールドマン', 'リーマン', '資産', 'リーマン日本法人', '負債総額', 'フィオリーナ氏', '規制当局', 'aig', '申請', 'バークレイズ', '取得', '企業', 'マケイン氏', 'rtc', '整理信託公社', '選挙', '麻生氏', 'ポールソン長官', '金融安定化策', '協議', '対案', '討論会', '買収', 'ベルギー', 'リード', '可決', '政権', 'ペイリン候補', '採決', '下院', '回答', '調査', '法案', '影響', '提案', '韓国', '銀行', 'gm', '軍事攻撃', '回復', '予定', 'オペル', '草案', 'ネタニヤフ首相', 'キューバ', '再開', '移民協議', 'クライスラー', '承認', '資産売却', '雲氏', 'ネット', '発射', 'メドベージェフ大統領', 'ブラウン首相', '開城工業団地', '大統領', 'ディーラー', '機関', '太陽電池', '実施', '改革案', 'ecb', 'ギリシャ', '日本', 'cnn', '方針', 'cia', '自爆攻撃']
# 138
# ----------------------------------------

# %%
data = countVect(data, sepfile_names)

# %%
dict_word = {"keiki":[], "bukka":[], "kinri":[], "money":[], "boueki":[], "koyou":[], "kojin":[], "kainyu":[], "oil":[], "kabu":[], "saiken":[], "youjin":[], "seiji":[]}
for d, name in zip(data, sepfile_names):
    dict_word[name] = d

# %%
print(dict_word)
# Out:
# {'bukka': [], 'koyou2_2_2': ['信用', '税還付', '稼働停止', '消費支出', 'fhfa', '定期昇給', '値下げ', '小型店', '現状維持', '破産', '最高水準', 'キャタピラー', '政権交代', '民間', '消費者態度指数', '販売'], 'saiken2_2_2': ['農水省', 'コアコアcpi', '消費者物価指数', '石油製品特殊要因', '試算', '収益性', '価格', 'シャープ', '液晶パネル', 'ジャガイモ', '搭載', '上昇圧力', 'cpi上昇率', '地域', '値上げ幅', '食品価格', '値上がり', 'コアcpi', '理解'], 'kinri': [], 'boueki2_2_2': ['対処', '石油備蓄', '原油在庫', '社長', 'ダウンサイドリスク', '製油所', '増産', 'ベネズエラ', '支持', '九州石油', '日石', '軽自動車', 'メリルリンチ', '原油相場', '輸入価格', '輸出価格', '高山', '利食い', 'サウジアラビア', 'ニューヨーク取引', '西尾社長', '需要減退', 'iea', 'ガソリンスタンド', 'サウジ', 'サミット', 'メッセージ', '西久保社長', '商品トレーディング', 'バイオ燃料', '急伸', '米原油需要', '打撃', 'nymex', '食料', 'レジ袋', 'ゴミ', '太陽光', '戦略備蓄石油', '同案', '想定', '供給ひっ迫', '金本位制', 'グルジア紛争', '見解', '被害', '鈴木会長', '薄膜式', '減産', '鉱山機械', '信用倍率', '国際商品市況', '統合', 'iata', '質問', '北海ブレント原油先物', '欧州市場', '最新', 'アナリスト予想平均', 'ロイターエスティメーツ', '消費国', '産油国', 'アンドレス', '大雨', '航空業界', '店頭デリバティブ', '日量', '新た', '前週比', '余剰生産能力', '生産目標', '準備通貨', '序盤', '日揮', '総会', '要望'], 'oil2_2_2': ['新華社', '貿易黒字', '寄与', '黒字幅', '貿易収支', '低下率', 'ロシア中銀', '経常利益', '経常収支', '労働日数調整後', '金融サミット'], 'oil': [], 'seiji': ['オバマ上院議員', '予備選', '候補者', '米nbc', '選出', '爆弾', 'ワイオミング州', '事態', '支持率', '獲得', 'クリントン上院議員', 'ニューハンプシャー州予備選挙', '撤退', '知事', 'wto', 'hud', '福田首相', 'シリア', '払い戻し', '文言', '大統領選挙', '民主党ノースカロライナ州予備選', '米メディア', '民主党インディアナ州予備選', '米cbsテレビ', '福田康夫氏', '辞任表明', '操業', '製油能力', '核施設', 'コミュニティ', 'ペイリン知事', 'グルジア', 'イラク', 'ペイリン氏', '書記', 'オバマ候補', '複数', 'アジア市場', '取引開始', '完了', 'リーマン日本法人', '負債総額', 'フィオリーナ氏', '規制当局', 'マケイン氏', '整理信託公社', '麻生氏', 'ポールソン長官', '対案', '討論会', 'ベルギー', 'リード', 'ペイリン候補', '採決', '下院', '軍事攻撃', 'オペル', '草案', 'ネタニヤフ首相', '再開', '移民協議', '資産売却', '雲氏', 'ネット', '発射', 'メドベージェフ大統領', '開城工業団地', 'cnn', 'cia', '自爆攻撃'], 'kinri2_2_2': ['ドル買い介入', '介入水準'], 'keiki': [], 'saiken': [], 'kojin': [], 'kainyu2_2_2': ['据え置き', 'ff金利', '緩和政策', 'グリーンスパン氏', '景気減速', 'ニュージーランド', 'nzier', '年内', '原材料高', '金融政策委員会', '短期金利', 'イングランド銀行', 'オフィシャルキャッシュレート', 'オーストラリア準備銀行', '白川総裁', 'pimco', '量的緩和', '引き下げ', '豪中銀', '用意', '提供', '英中央銀行', '追加利下げ', 'レポレート', 'snb', '手段', '市場機能', '中国人民銀行', 'ロート総裁', '物金利', '外銀', 'ローン金利', '英国債', 'スイス中銀', '下限', '基礎利益', 'libor', 'cfpa', '主要通貨', '資産買い入れプログラム', '国債市場', '鳩山内閣', '信頼', '国債'], 'koyou': [], 'bukka2_2_2': ['住宅ローン融資額', '一致指数', '住宅着工件数', '一段', '基本シナリオ', '文書', '税払い戻し', '予算教書', 'セル', '安定', 'スロバキア', '欧州委員会', '欧州委', '債権回収業者', '速報値', 'スタグフレーション', 'メドベージェフ氏', '数値', '設備稼働率', 'ノーザン', '証言', '民間エコノミスト', '投機筋', 'マイナス成長', '着工件数', '許可件数', 'bba', '新設住宅着工戸数', 'adb', '生産性', 'ユーロ導入', '信認', '四川省', 'mba', 'ci', '促進', '実質gdp', 'グループ', 'トゥンペルグゲレル専務理事', '改定段階', '次期大統領', '産業', '全会一致', '中期的', '支援策', '調整', '歳入', 'カバードボンド', 'cdo', 'カナダドル', 'すかいらーく', 'ガソリン', '内需', '都市部固定資産投資', '自動車部品', 'フランス', 'ホープナウ', '米景気', '新規受注', 'タイ', '増値税', '推定値', 'ci一致指数', '下方修整', 'cb', '先行指数', 'オフィスビル', '金価格', '経済指標', '商品価格', '日本経済', 'gdp伸び率', '中国国家統計局', '国内', 'ポジション', 'アイスランド', 'グロス経済技術相', '耐久財受注', 'クリスマス商戦', '商戦', 'nber', '百貨店', 'ロイター予測', '明示', '税制抜本改革', '卸売在庫', '批准', '公聴会', '事業', '金融システム', '国家統計局', 'ケース', '基礎的財政収支', 'item', '鉱工業受注', '最低', 'ノーザンロック', '温家宝首相', 'cmo', 'mbs', '銀行救済策', '住宅保有者', '統計局', '記者会見', '署名', '削減', '崩壊', 'ntt東', '債務', '会議', '支給', '借り手', 'aiada', '申請総数', '応札', '財政出動', '受注', '改定値', '数値目標', '英経済', '受給総数', '成長率予測', '撤回', '対gdp比', '専務理事', '感染', 'メキシコ経済', 'サーベラス', '増配', '幾分', '株式保有リスク', 'gdpギャップ', '約束', '歳出改革', '兆し', 'ダーリング財務相', '国務院', 'ドイツ', 'bis', 'cfnai', 'トレンド', '経済成長率', '耐久財', '売り上げ', '一戸建て住宅', '雇用喪失', '部分', '正常化', '所長', 'kipf', '自民党', '尚早', 'キャドバリー', 'ニューヨーク金先物', '行動', '差し押さえ件数', '出口政策', '実行', '確固', '子ども手当', '債券', '見直し', '貸家', 'ファニー', 'フレディ', '伸び率予想', '年央経済財政見通し', '豪政府', '人員削減数', '削減数', '景気拡大', '柔軟', '金相場', '懇談会', '中間所得層', 'うかつ', '遺憾', '温暖化ガス排出量', 'ポルトガル', '景気先行指数', 'uae'], 'money2_2_2': ['ブルーチップ', 'クレジットカード', 'ilo', '緊急利下げ', '利益見通し', '失業者数', '総務省', '新規雇用率', '連携', '雇用創出', '失業保険', '失業対策法案', '延長', '給付期間', 'オバマ次期大統領', '悲観的', 'cnbcテレビ', '方向性', '季節調整後', '全人代', '不況', '政策対応', '正当化', '雇用者数', '倒償却率', '物件', 'フィッチ', 'デフォルト率', '刺激策', '緩やか', '就業者数', '意見交換', '論評', '突破', '節目', '米雇用統計', '価格帯', '赤字額', '責任', '演説', 'イリノイ州', '雇用対策', 'プライマ ...

# %%
writeJSON(dict_word)

print("-----頻出語の抽出完了-----")
# cv.tfIdf(data)
# countvectorizer(出現頻度推定)
# cv.countVect(df, sepfile_names[:-1])
# Out:
# -----頻出語の抽出完了-----
